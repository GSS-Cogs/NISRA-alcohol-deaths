# %% [markdown]
# Table 1a:  Number of alcohol related deaths by sex and registration year, 2001-2016 - (new definition)

# %%
from gssutils import *

if is_interactive():
    import requests
    from cachecontrol import CacheControl
    from cachecontrol.caches.file_cache import FileCache
    from cachecontrol.heuristics import LastModified
    from pathlib import Path

    session = CacheControl(requests.Session(),
                           cache=FileCache('.cache'),
                           heuristic=LastModified())

    sourceFolder = Path('in')
    sourceFolder.mkdir(exist_ok=True)

    inputURL = 'https://www.nisra.gov.uk/sites/nisra.gov.uk/files/publications/Alcohol_Tables_16_0.xls'
    inputFile = sourceFolder / 'Alcohol_Tables_16_0.xls'
    response = session.get(inputURL)
    with open(inputFile, 'wb') as f:
      f.write(response.content)
    tab = loadxlstabs(inputFile, sheetids='Table 1a')[0]
# Out:
# Loading in/Alcohol_Tables_16_0.xls which has size 969216 bytes
# Table names: ['Table 1a']

# %%
observations = tab.excel_ref('B5').expand(DOWN).expand(RIGHT).is_not_blank()

# %%
observations
# Out:
# {<B12 243.0>, <D13 84.0>, <C20 184.0>, <B21 3636.0>, <C14 175.0>, <D8 62.0>, <B11 238.0>, <D21 1151.0>, <B13 249.0>, <C5 117.0>, <D19 97.0>, <D18 64.0>, <C19 185.0>, <B20 289.0>, <B14 260.0>, <D12 78.0>, <B16 244.0>, <D14 85.0>, <D15 67.0>, <B5 178.0>, <D6 53.0>, <B8 204.0>, <B18 219.0>, <C6 141.0>, <C21 2485.0>, <B9 217.0>, <D7 63.0>, <C9 155.0>, <C7 112.0>, <B7 175.0>, <D9 62.0>, <C8 142.0>, <C15 161.0>, <D11 73.0>, <C18 155.0>, <C11 165.0>, <C17 151.0>, <C16 159.0>, <D16 85.0>, <C12 165.0>, <D17 55.0>, <B6 194.0>, <D20 105.0>, <B10 210.0>, <D10 57.0>, <B19 282.0>, <C10 153.0>, <D5 61.0>, <B15 228.0>, <B17 206.0>, <C13 165.0>}

# %%
sex = tab.excel_ref('B4').expand(RIGHT).is_not_blank()
sex
# Out:
# {<C4 'Male'>, <D4 'Female'>}

# %%
Year = tab.excel_ref('A5').expand(DOWN) - tab.excel_ref('A22').expand(DOWN)  
Year
# Out:
# {<A17 2013.0>, <A21 'Total (2001-2016)'>, <A5 2001.0>, <A12 2008.0>, <A14 2010.0>, <A8 2004.0>, <A10 2006.0>, <A13 2009.0>, <A20 2016.0>, <A7 2003.0>, <A11 2007.0>, <A18 2014.0>, <A16 2012.0>, <A9 2005.0>, <A6 2002.0>, <A19 2015.0>, <A15 2011.0>}

# %%
Dimensions = [
            HDim(Year,'Year',DIRECTLY,LEFT),
            HDim(sex,'Sex',DIRECTLY,ABOVE),
            HDimConst('Measure Type', 'Count'),
            HDimConst('Unit','People')
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
if is_interactive():
    savepreviewhtml(c1)
# Out:
# <div id="injblock1001">
# <style>
# table.ex, table.exkey { border: thin black solid }
# table.ex td, table.ex tr { border: none }
# table.ex td:hover { border: thin blue solid }
# table.ex td.excOBS:hover { border: thin red solid }
# table.ex td.selected { border: thick red solid }
# </style>
#
#
# <table class="exkey">
# <tr><td class="xc0" style="background-color:Aqua">OBS</td><td class="xc1" style="background-color:LightGreen">Year</td><td class="xc2" style="background-color:MistyRose">Sex</td></tr></table>
# {
#     Dclickedcell = this;
#     console.log("jjjj", this);
#     var rgc = new RegExp('(^|\b)' + "selected".split(' ').join('|') + '(\b|$)', 'gi');
#     Array.prototype.forEach.call(document.querySelectorAll("div#"+jdividNUM+" table.ex td.selected"), function(el, i) {
#         if (el.classList)  el.classList.remove("selected");
#         else  el.className = el.className.replace(rgc, ' ');
#     });
#     if (this.classList)  this.classList.add("selected");
#     else this.className += ' ' + "selected";
#
#     var dimpairs = jslookup[this.title];
#     if (dimpairs !== undefined) {
#         for (var i = 1; i < dimpairs.length; i += 2) {
#             var row = document.querySelectorAll("div#"+jdividNUM+" table.ex tr")[dimpairs[i]];

# %%
new_table = c1.topandas()
new_table
# Out:
#        OBS               Year     Sex Measure Type    Unit
# 0    178.0             2001.0    None        Count  People
# 1    117.0             2001.0    Male        Count  People
# 2     61.0             2001.0  Female        Count  People
# 3    194.0             2002.0    None        Count  People
# 4    141.0             2002.0    Male        Count  People
# 5     53.0             2002.0  Female        Count  People
# 6    175.0             2003.0    None        Count  People
# 7    112.0             2003.0    Male        Count  People
# 8     63.0             2003.0  Female        Count  People
# 9    204.0             2004.0    None        Count  People
# 10   142.0             2004.0    Male        Count  People
# 11    62.0             2004.0  Female        Count  People
# 12   217.0             2005.0    None        Count  People
# 13   155.0             2005.0    Male        Count  People
# 14    62.0             2005.0  Female        Count  People
# 15   210.0             2006.0    None        Count  People
# 16   153.0             2006.0    Male        Count  People
# 17    57.0             2006.0  Female        Count  People
# 18   238.0             2007.0    None        Count  People
# 19   165.0             2007.0    Male        Count  People
# 20    73.0             2007.0  Female        Count  People
# 21   243.0             2008.0    None        Count  People
# 22   165.0             2008.0    Male        Count  People
# 23    78.0             2008.0  Female        Count  People
# 24   249.0             2009.0    None        Count  People
# 25   165.0             2009.0    Male        Count  People
# 26    84.0             2009.0  Female        Count  People
# 27   260.0             2010.0    None        Count  People
# 28   175.0             2010.0    Male        Count  People
# 29    85.0             2010.0  Female        Count  People
# 30   228.0             2011.0    None        Count  People
# 31   161.0             2011.0    Male        Count  People
# 32    67.0             2011.0  Female        Count  People
# 33   244.0             2012.0    None        Count  People
# 34   159.0             2012.0    Male        Count  People
# 35    85.0             2012.0  Female        Count  People
# 36   206.0             2013.0    None        Count  People
# 37   151.0             2013.0    Male        Count  People
# 38    55.0             2013.0  Female        Count  People
# 39   219.0             2014.0    None        Count  People
# 40   155.0             2014.0    Male        Count  People
# 41    64.0             2014.0  Female        Count  People
# 42   282.0             2015.0    None        Count  People
# 43   185.0             2015.0    Male        Count  People
# 44    97.0             2015.0  Female        Count  People
# 45   289.0             2016.0    None        Count  People
# 46   184.0             2016.0    Male        Count  People
# 47   105.0             2016.0  Female        Count  People
# 48  3636.0  Total (2001-2016)    None        Count  People
# 49  2485.0  Total (2001-2016)    Male        Count  People
# 50  1151.0  Total (2001-2016)  Female        Count  People

# %%
new_table['Sex'].fillna('Persons', inplace = True)

# %%
new_table
# Out:
#        OBS               Year      Sex Measure Type    Unit
# 0    178.0             2001.0  Persons        Count  People
# 1    117.0             2001.0     Male        Count  People
# 2     61.0             2001.0   Female        Count  People
# 3    194.0             2002.0  Persons        Count  People
# 4    141.0             2002.0     Male        Count  People
# 5     53.0             2002.0   Female        Count  People
# 6    175.0             2003.0  Persons        Count  People
# 7    112.0             2003.0     Male        Count  People
# 8     63.0             2003.0   Female        Count  People
# 9    204.0             2004.0  Persons        Count  People
# 10   142.0             2004.0     Male        Count  People
# 11    62.0             2004.0   Female        Count  People
# 12   217.0             2005.0  Persons        Count  People
# 13   155.0             2005.0     Male        Count  People
# 14    62.0             2005.0   Female        Count  People
# 15   210.0             2006.0  Persons        Count  People
# 16   153.0             2006.0     Male        Count  People
# 17    57.0             2006.0   Female        Count  People
# 18   238.0             2007.0  Persons        Count  People
# 19   165.0             2007.0     Male        Count  People
# 20    73.0             2007.0   Female        Count  People
# 21   243.0             2008.0  Persons        Count  People
# 22   165.0             2008.0     Male        Count  People
# 23    78.0             2008.0   Female        Count  People
# 24   249.0             2009.0  Persons        Count  People
# 25   165.0             2009.0     Male        Count  People
# 26    84.0             2009.0   Female        Count  People
# 27   260.0             2010.0  Persons        Count  People
# 28   175.0             2010.0     Male        Count  People
# 29    85.0             2010.0   Female        Count  People
# 30   228.0             2011.0  Persons        Count  People
# 31   161.0             2011.0     Male        Count  People
# 32    67.0             2011.0   Female        Count  People
# 33   244.0             2012.0  Persons        Count  People
# 34   159.0             2012.0     Male        Count  People
# 35    85.0             2012.0   Female        Count  People
# 36   206.0             2013.0  Persons        Count  People
# 37   151.0             2013.0     Male        Count  People
# 38    55.0             2013.0   Female        Count  People
# 39   219.0             2014.0  Persons        Count  People
# 40   155.0             2014.0     Male        Count  People
# 41    64.0             2014.0   Female        Count  People
# 42   282.0             2015.0  Persons        Count  People
# 43   185.0             2015.0     Male        Count  People
# 44    97.0             2015.0   Female        Count  People
# 45   289.0             2016.0  Persons        Count  People
# 46   184.0             2016.0     Male        Count  People
# 47   105.0             2016.0   Female        Count  People
# 48  3636.0  Total (2001-2016)  Persons        Count  People
# 49  2485.0  Total (2001-2016)     Male        Count  People
# 50  1151.0  Total (2001-2016)   Female        Count  People

# %%
new_table['Year'] = pd.to_numeric(new_table['Year'], errors='coerce').fillna(0)

# %%
new_table['Year'] = new_table['Year'].astype(int)

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
new_table['Year'] = new_table['Year'].astype(str)

# %%
new_table['Value'] = new_table['Value'].astype(int)

# %%
new_table.dtypes
# Out:
# Value            int64
# Year            object
# Sex             object
# Measure Type    object
# Unit            object
# dtype: object

# %%
new_table.tail(5)
# Out:
#     Value  Year      Sex Measure Type    Unit
# 46    184  2016     Male        Count  People
# 47    105  2016   Female        Count  People
# 48   3636     0  Persons        Count  People
# 49   2485     0     Male        Count  People
# 50   1151     0   Female        Count  People

# %%
def user_perc(x):
    
    if str(x) == '0':
        return '2001-2016'
    else:
        return x
    
new_table['Year'] = new_table.apply(lambda row: user_perc(row['Year']), axis = 1)

# %%
new_table = new_table[['Year','Sex','Measure Type','Value','Unit']]

# %%
new_table.head(5)
# Out:
#    Year      Sex Measure Type  Value    Unit
# 0  2001  Persons        Count    178  People
# 1  2001     Male        Count    117  People
# 2  2001   Female        Count     61  People
# 3  2002  Persons        Count    194  People
# 4  2002     Male        Count    141  People

# %%
if is_interactive():
    destinationFolder = Path('out')
    destinationFolder.mkdir(exist_ok=True, parents=True)

    new_table.to_csv(destinationFolder / ('tab1a.csv'), index = False)
