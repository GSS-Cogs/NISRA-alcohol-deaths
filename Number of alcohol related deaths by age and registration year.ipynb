# %% [markdown]
# Table 2a:  Number of alcohol related deaths by age and registration year, 2006-2016 - (new definition)

# %%
from databaker.framework import *
import pandas as pd

# %%
import requests
from cachecontrol import CacheControl
from cachecontrol.caches.file_cache import FileCache
from cachecontrol.heuristics import LastModified
from pathlib import Path

session = CacheControl(requests.Session(),
                       cache=FileCache('.cache'),
                       heuristic=LastModified())

sourceFolder = Path('in')
sourceFolder.mkdir(exist_ok=True)

inputURL = 'https://www.nisra.gov.uk/sites/nisra.gov.uk/files/publications/Alcohol_Tables_16_0.xls'
inputFile = sourceFolder / 'Alcohol_Tables_16_0.xls'
response = session.get(inputURL)
with open(inputFile, 'wb') as f:
  f.write(response.content)

# %%
tab = loadxlstabs(inputFile, sheetids='Table 2a')[0]
# Out:
# Loading in\Alcohol_Tables_16_0.xls which has size 969216 bytes
# Table names: ['Table 2a']

# %%
observations = tab.excel_ref('B5').expand(DOWN).expand(RIGHT).is_not_blank()

# %%
observations
# Out:
# {<E13 28.0>, <E16 442.0>, <H5 22.0>, <H15 47.0>, <J8 53.0>, <G9 76.0>, <G11 75.0>, <B9 260.0>, <C12 0.0>, <B15 289.0>, <F12 76.0>, <F9 102.0>, <B10 228.0>, <D15 10.0>, <H12 30.0>, <J11 53.0>, <I9 7.0>, <I6 8.0>, <G16 774.0>, <G8 71.0>, <C14 1.0>, <F8 92.0>, <E15 31.0>, <B12 206.0>, <B13 219.0>, <E5 40.0>, <F13 76.0>, <J9 52.5>, <G5 54.0>, <E11 51.0>, <J6 50.0>, <D6 9.0>, <H16 341.0>, <D14 6.0>, <D9 12.0>, <J12 54.0>, <H13 29.0>, <C15 1.0>, <J15 55.0>, <D5 5.0>, <C6 1.0>, <D12 7.0>, <G10 62.0>, <D13 4.0>, <H6 25.0>, <C8 0.0>, <I12 2.0>, <I13 9.0>, <H14 40.0>, <I7 7.0>, <F6 77.0>, <E12 27.0>, <E10 52.0>, <F16 939.0>, <C9 0.0>, <I16 89.0>, <F5 78.0>, <G6 56.0>, <B7 243.0>, <I11 5.0>, <J14 54.0>, <G14 79.0>, <E6 62.0>, <H11 30.0>, <F15 90.0>, <H8 27.0>, <E7 33.0>, <G7 69.0>, <J13 55.0>, <D11 5.0>, <B14 282.0>, <F11 77.0>, <I15 15.0>, <C11 1.0>, <J5 52.0>, <B6 238.0>, <E8 43.0>, <C16 5.0>, <F10 73.0>, <D7 6.0>, <C10 0.0>, <B16 2668.0>, <F14 104.0>, <I10 8.0>, <D8 8.0>, <F7 94.0>, <G15 95.0>, <B8 249.0>, <J7 53.0>, <J10 52.0>, <B11 244.0>, <D16 78.0>, <I5 10.0>, <I14 10.0>, <I8 8.0>, <G12 64.0>, <C5 1.0>, <J16 54.0>, <H7 34.0>, <H9 30.0>, <G13 73.0>, <E14 42.0>, <B5 210.0>, <E9 33.0>, <H10 27.0>, <D10 6.0>, <C13 0.0>, <C7 0.0>}

# %%
age = tab.excel_ref('B4').expand(RIGHT).is_not_blank()
age
# Out:
# {<D4 '25-34'>, <G4 '55-64'>, <E4 '35-44'>, <C4 'Under 25'>, <F4 '45-54'>, <H4 '65-74'>, <I4 '75 and over'>}

# %%
age1 = tab.excel_ref('B3').expand(RIGHT).is_not_blank()
age1
# Out:
# {<C3 'Age Group'>, <J3 'Median Age'>, <B3 'All Ages'>}

# %%
Year = tab.excel_ref('A5').expand(DOWN) - tab.excel_ref('A17').expand(DOWN)  
Year
# Out:
# {<A10 2011.0>, <A16 'Total (2006-2016)'>, <A6 2007.0>, <A13 2014.0>, <A8 2009.0>, <A12 2013.0>, <A7 2008.0>, <A11 2012.0>, <A15 2016.0>, <A14 2015.0>, <A9 2010.0>, <A5 2006.0>}

# %%
Dimensions = [
            HDim(Year,'Year',DIRECTLY,LEFT),
            HDim(age, 'Age',DIRECTLY,ABOVE),
            HDim(age1, 'Age1', DIRECTLY, ABOVE),
            HDimConst('Measure Type', 'Count'),
            HDimConst('Unit','People')
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
savepreviewhtml(c1)
# Out:
# <div id="injblock1001">
# <style>
# table.ex, table.exkey { border: thin black solid }
# table.ex td, table.ex tr { border: none }
# table.ex td:hover { border: thin blue solid }
# table.ex td.excOBS:hover { border: thin red solid }
# table.ex td.selected { border: thick red solid }
# </style>
#
#
# <table class="exkey">
# <tr><td class="xc0" style="background-color:Aqua">OBS</td><td class="xc1" style="background-color:LightGreen">Year</td><td class="xc2" style="background-color:MistyRose">Age</td><td class="xc3" style="background-color:LightGray">Age1</td></tr></table>
#
# <table class="ex">
# <caption style="text-align:center; padding:0px; caption-side:bottom">Table 2a</caption>
# <tr><td style="font-weight:bold" title="0 0">Table 2a:  Number of alcohol related deaths by age and registration year, 2006-2016 - (new definition)</td><td title="1 0"></td><td title="2 0"></td><td title="3 0"></td><td title="4 0"></td><td title="5 0"></td><td title="6 0"></td><td title="7 0"></td><td title="8 0"></td><td title="9 0"></td><td title="10 0"></td><td title="11 0"></td></tr>
# <tr><td title="0 1"></td><td title="1 1"></td><td title="2 1"></td><td title="3 1"></td><td title="4 1"></td><td title="5 1"></td><td title="6 1"></td><td title="7 1"></td><td title="8 1"></td><td title="9 1"></td><td title="10 1"></td><td title="11 1"></td></tr>
# <tr><td title="0 2">Registration Year</td><td style="background-color:LightGray" title="1 2">All Ages</td><td style="background-color:LightGray" title="2 2">Age Group</td><td title="3 2"></td><td title="4 2"></td><td title="5 2"></td><td title="6 2"></td><td title="7 2"></td><td title="8 2"></td><td style="background-color:LightGray" title="9 2">Median Age</td><td title="10 2"></td><td title="11 2"></td></tr>
# <tr><td title="0 3"></td><td title="1 3"></td><td style="background-color:MistyRose" title="2 3">Under 25</td><td style="background-color:MistyRose" title="3 3">25-34</td><td style="background-color:MistyRose" title="4 3">35-44</td><td style="background-color:MistyRose" title="5 3">45-54</td><td style="background-color:MistyRose" title="6 3">55-64</td><td style="background-color:MistyRose" title="7 3">65-74</td><td style="background-color:MistyRose" title="8 3">75 and over</td><td title="9 3"></td><td title="10 3"></td><td title="11 3"></td></tr>
# <tr><td style="background-color:LightGreen" title="0 4">2006.0</td><td style="background-color:Aqua;font-weight:bold" title="1 4">210.0</td><td style="background-color:Aqua" title="2 4">1.0</td><td style="background-color:Aqua" title="3 4">5.0</td><td style="background-color:Aqua" title="4 4">40.0</td><td style="background-color:Aqua" title="5 4">78.0</td><td style="background-color:Aqua" title="6 4">54.0</td><td style="background-color:Aqua" title="7 4">22.0</td><td style="background-color:Aqua" title="8 4">10.0</td><td style="background-color:Aqua" title="9 4">52.0</td><td title="10 4"></td><td title="11 4"></td></tr>
# <tr><td style="background-color:LightGreen" title="0 5">2007.0</td><td style="background-color:Aqua;font-weight:bold" title="1 5">238.0</td><td style="background-color:Aqua" title="2 5">1.0</td><td style="background-color:Aqua" title="3 5">9.0</td><td style="background-color:Aqua" title="4 5">62.0</td><td style="background-color:Aqua" title="5 5">77.0</td><td style="background-color:Aqua" title="6 5">56.0</td><td style="background-color:Aqua" title="7 5">25.0</td><td style="background-color:Aqua" title="8 5">8.0</td><td style="background-color:Aqua" title="9 5">50.0</td><td title="10 5"></td><td title="11 5"></td></tr>
# <tr><td style="background-color:LightGreen" title="0 6">2008.0</td><td style="background-color:Aqua;font-weight:bold" title="1 6">243.0</td><td style="background-color:Aqua" title="2 6">0.0</td><td style="background-color:Aqua" title="3 6">6.0</td><td style="background-color:Aqua" title="4 6">33.0</td><td style="background-color:Aqua" title="5 6">94.0</td><td style="background-color:Aqua" title="6 6">69.0</td><td style="background-color:Aqua" title="7 6">34.0</td><td style="background-color:Aqua" title="8 6">7.0</td><td style="background-color:Aqua" title="9 6">53.0</td><td title="10 6"></td><td title="11 6"></td></tr>
# <tr><td style="background-color:LightGreen" title="0 7">2009.0</td><td style="background-color:Aqua;font-weight:bold" title="1 7">249.0</td><td style="background-color:Aqua" title="2 7">0.0</td><td style="background-color:Aqua" title="3 7">8.0</td><td style="background-color:Aqua" title="4 7">43.0</td><td style="background-color:Aqua" title="5 7">92.0</td><td style="background-color:Aqua" title="6 7">71.0</td><td style="background-color:Aqua" title="7 7">27.0</td><td style="background-color:Aqua" title="8 7">8.0</td><td style="background-color:Aqua" title="9 7">53.0</td><td title="10 7"></td><td title="11 7"></td></tr>
# <tr><td style="background-color:LightGreen" title="0 8">2010.0</td><td style="background-color:Aqua;font-weight:bold" title="1 8">260.0</td><td style="background-color:Aqua" title="2 8">0.0</td><td style="background-color:Aqua" title="3 8">12.0</td><td style="background-color:Aqua" title="4 8">33.0</td><td style="background-color:Aqua" title="5 8">102.0</td><td style="background-color:Aqua" title="6 8">76.0</td><td style="background-color:Aqua" title="7 8">30.0</td><td style="background-color:Aqua" title="8 8">7.0</td><td style="background-color:Aqua" title="9 8">52.5</td><td title="10 8"></td><td title="11 8"></td></tr>
# <tr><td style="background-color:LightGreen" title="0 9">2011.0</td><td style="background-color:Aqua;font-weight:bold" title="1 9">228.0</td><td style="background-color:Aqua" title="2 9">0.0</td><td style="background-color:Aqua" title="3 9">6.0</td><td style="background-color:Aqua" title="4 9">52.0</td><td style="background-color:Aqua" title="5 9">73.0</td><td style="background-color:Aqua" title="6 9">62.0</td><td style="background-color:Aqua" title="7 9">27.0</td><td style="background-color:Aqua" title="8 9">8.0</td><td style="background-color:Aqua" title="9 9">52.0</td><td title="10 9"></td><td title="11 9"></td></tr>
# <tr><td style="background-color:LightGreen" title="0 10">2012.0</td><td style="background-color:Aqua;font-weight:bold" title="1 10">244.0</td><td style="background-color:Aqua" title="2 10">1.0</td><td style="background-color:Aqua" title="3 10">5.0</td><td style="background-color:Aqua" title="4 10">51.0</td><td style="background-color:Aqua" title="5 10">77.0</td><td style="background-color:Aqua" title="6 10">75.0</td><td style="background-color:Aqua" title="7 10">30.0</td><td style="background-color:Aqua" title="8 10">5.0</td><td style="background-color:Aqua" title="9 10">53.0</td><td title="10 10"></td><td title="11 10"></td></tr>
# <tr><td style="background-color:LightGreen" title="0 11">2013.0</td><td style="background-color:Aqua;font-weight:bold" title="1 11">206.0</td><td style="background-color:Aqua" title="2 11">0.0</td><td style="background-color:Aqua" title="3 11">7.0</td><td style="background-color:Aqua" title="4 11">27.0</td><td style="background-color:Aqua" title="5 11">76.0</td><td style="background-color:Aqua" title="6 11">64.0</td><td style="background-color:Aqua" title="7 11">30.0</td><td style="background-color:Aqua" title="8 11">2.0</td><td style="background-color:Aqua" title="9 11">54.0</td><td title="10 11"></td><td title="11 11"></td></tr>
# <tr><td style="background-color:LightGreen" title="0 12">2014.0</td><td style="background-color:Aqua;font-weight:bold" title="1 12">219.0</td><td style="background-color:Aqua" title="2 12">0.0</td><td style="background-color:Aqua" title="3 12">4.0</td><td style="background-color:Aqua" title="4 12">28.0</td><td style="background-color:Aqua" title="5 12">76.0</td><td style="background-color:Aqua" title="6 12">73.0</td><td style="background-color:Aqua" title="7 12">29.0</td><td style="background-color:Aqua" title="8 12">9.0</td><td style="background-color:Aqua" title="9 12">55.0</td><td title="10 12"></td><td title="11 12"></td></tr>
# <tr><td style="background-color:

# %%
new_table = c1.topandas()
new_table
# Out:
#         OBS               Year          Age        Age1 Measure Type    Unit
# 0     210.0             2006.0         None    All Ages        Count  People
# 1       1.0             2006.0     Under 25   Age Group        Count  People
# 2       5.0             2006.0        25-34        None        Count  People
# 3      40.0             2006.0        35-44        None        Count  People
# 4      78.0             2006.0        45-54        None        Count  People
# 5      54.0             2006.0        55-64        None        Count  People
# 6      22.0             2006.0        65-74        None        Count  People
# 7      10.0             2006.0  75 and over        None        Count  People
# 8      52.0             2006.0         None  Median Age        Count  People
# 9     238.0             2007.0         None    All Ages        Count  People
# 10      1.0             2007.0     Under 25   Age Group        Count  People
# 11      9.0             2007.0        25-34        None        Count  People
# 12     62.0             2007.0        35-44        None        Count  People
# 13     77.0             2007.0        45-54        None        Count  People
# 14     56.0             2007.0        55-64        None        Count  People
# 15     25.0             2007.0        65-74        None        Count  People
# 16      8.0             2007.0  75 and over        None        Count  People
# 17     50.0             2007.0         None  Median Age        Count  People
# 18    243.0             2008.0         None    All Ages        Count  People
# 19      0.0             2008.0     Under 25   Age Group        Count  People
# 20      6.0             2008.0        25-34        None        Count  People
# 21     33.0             2008.0        35-44        None        Count  People
# 22     94.0             2008.0        45-54        None        Count  People
# 23     69.0             2008.0        55-64        None        Count  People
# 24     34.0             2008.0        65-74        None        Count  People
# 25      7.0             2008.0  75 and over        None        Count  People
# 26     53.0             2008.0         None  Median Age        Count  People
# 27    249.0             2009.0         None    All Ages        Count  People
# 28      0.0             2009.0     Under 25   Age Group        Count  People
# 29      8.0             2009.0        25-34        None        Count  People
# ..      ...                ...          ...         ...          ...     ...
# 78     29.0             2014.0        65-74        None        Count  People
# 79      9.0             2014.0  75 and over        None        Count  People
# 80     55.0             2014.0         None  Median Age        Count  People
# 81    282.0             2015.0         None    All Ages        Count  People
# 82      1.0             2015.0     Under 25   Age Group        Count  People
# 83      6.0             2015.0        25-34        None        Count  People
# 84     42.0             2015.0        35-44        None        Count  People
# 85    104.0             2015.0        45-54        None        Count  People
# 86     79.0             2015.0        55-64        None        Count  People
# 87     40.0             2015.0        65-74        None        Count  People
# 88     10.0             2015.0  75 and over        None        Count  People
# 89     54.0             2015.0         None  Median Age        Count  People
# 90    289.0             2016.0         None    All Ages        Count  People
# 91      1.0             2016.0     Under 25   Age Group        Count  People
# 92     10.0             2016.0        25-34        None        Count  People
# 93     31.0             2016.0        35-44        None        Count  People
# 94     90.0             2016.0        45-54        None        Count  People
# 95     95.0             2016.0        55-64        None        Count  People
# 96     47.0             2016.0        65-74        None        Count  People
# 97     15.0             2016.0  75 and over        None        Count  People
# 98     55.0             2016.0         None  Median Age        Count  People
# 99   2668.0  Total (2006-2016)         None    All Ages        Count  People
# 100     5.0  Total (2006-2016)     Under 25   Age Group        Count  People
# 101    78.0  Total (2006-2016)        25-34        None        Count  People
# 102   442.0  Total (2006-2016)        35-44        None        Count  People
# 103   939.0  Total (2006-2016)        45-54        None        Count  People
# 104   774.0  Total (2006-2016)        55-64        None        Count  People
# 105   341.0  Total (2006-2016)        65-74        None        Count  People
# 106    89.0  Total (2006-2016)  75 and over        None        Count  People
# 107    54.0  Total (2006-2016)         None  Median Age        Count  People
#
# [108 rows x 6 columns]

# %%
new_table['Year'] = pd.to_numeric(new_table['Year'], errors='coerce').fillna(0)

# %%
new_table['Year'] = new_table['Year'].astype(int)

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
new_table['Year'] = new_table['Year'].astype(str)

# %%
new_table['Value'] = new_table['Value'].astype(int)

# %%
new_table.dtypes
# Out:
# Value            int32
# Year            object
# Age             object
# Age1            object
# Measure Type    object
# Unit            object
# dtype: object

# %%
new_table.tail(5)
# Out:
#      Value Year          Age        Age1 Measure Type    Unit
# 103    939    0        45-54        None        Count  People
# 104    774    0        55-64        None        Count  People
# 105    341    0        65-74        None        Count  People
# 106     89    0  75 and over        None        Count  People
# 107     54    0         None  Median Age        Count  People

# %%
def user_perc(x):
    
    if str(x) == '0':
        return '2001-2016'
    else:
        return x
    
new_table['Year'] = new_table.apply(lambda row: user_perc(row['Year']), axis = 1)

# %%
def user_perc1(x,y):    
    if str(x) == 'Median Age':
        return 'Median Age'
    else:
        return y        
    
new_table['Age'] = new_table.apply(lambda row: user_perc1(row['Age1'], row['Age']), axis = 1)

# %%
def user_perc2(x,y):    
    if str(x) == 'All Ages':
        return 'All Ages'
    else:
        return y        
    
new_table['Age'] = new_table.apply(lambda row: user_perc2(row['Age1'], row['Age']), axis = 1)

# %%
new_table
# Out:
#      Value       Year          Age        Age1 Measure Type    Unit
# 0      210       2006     All Ages    All Ages        Count  People
# 1        1       2006     Under 25   Age Group        Count  People
# 2        5       2006        25-34        None        Count  People
# 3       40       2006        35-44        None        Count  People
# 4       78       2006        45-54        None        Count  People
# 5       54       2006        55-64        None        Count  People
# 6       22       2006        65-74        None        Count  People
# 7       10       2006  75 and over        None        Count  People
# 8       52       2006   Median Age  Median Age        Count  People
# 9      238       2007     All Ages    All Ages        Count  People
# 10       1       2007     Under 25   Age Group        Count  People
# 11       9       2007        25-34        None        Count  People
# 12      62       2007        35-44        None        Count  People
# 13      77       2007        45-54        None        Count  People
# 14      56       2007        55-64        None        Count  People
# 15      25       2007        65-74        None        Count  People
# 16       8       2007  75 and over        None        Count  People
# 17      50       2007   Median Age  Median Age        Count  People
# 18     243       2008     All Ages    All Ages        Count  People
# 19       0       2008     Under 25   Age Group        Count  People
# 20       6       2008        25-34        None        Count  People
# 21      33       2008        35-44        None        Count  People
# 22      94       2008        45-54        None        Count  People
# 23      69       2008        55-64        None        Count  People
# 24      34       2008        65-74        None        Count  People
# 25       7       2008  75 and over        None        Count  People
# 26      53       2008   Median Age  Median Age        Count  People
# 27     249       2009     All Ages    All Ages        Count  People
# 28       0       2009     Under 25   Age Group        Count  People
# 29       8       2009        25-34        None        Count  People
# ..     ...        ...          ...         ...          ...     ...
# 78      29       2014        65-74        None        Count  People
# 79       9       2014  75 and over        None        Count  People
# 80      55       2014   Median Age  Median Age        Count  People
# 81     282       2015     All Ages    All Ages        Count  People
# 82       1       2015     Under 25   Age Group        Count  People
# 83       6       2015        25-34        None        Count  People
# 84      42       2015        35-44        None        Count  People
# 85     104       2015        45-54        None        Count  People
# 86      79       2015        55-64        None        Count  People
# 87      40       2015        65-74        None        Count  People
# 88      10       2015  75 and over        None        Count  People
# 89      54       2015   Median Age  Median Age        Count  People
# 90     289       2016     All Ages    All Ages        Count  People
# 91       1       2016     Under 25   Age Group        Count  People
# 92      10       2016        25-34        None        Count  People
# 93      31       2016        35-44        None        Count  People
# 94      90       2016        45-54        None        Count  People
# 95      95       2016        55-64        None        Count  People
# 96      47       2016        65-74        None        Count  People
# 97      15       2016  75 and over        None        Count  People
# 98      55       2016   Median Age  Median Age        Count  People
# 99    2668  2001-2016     All Ages    All Ages        Count  People
# 100      5  2001-2016     Under 25   Age Group        Count  People
# 101     78  2001-2016        25-34        None        Count  People
# 102    442  2001-2016        35-44        None        Count  People
# 103    939  2001-2016        45-54        None        Count  People
# 104    774  2001-2016        55-64        None        Count  People
# 105    341  2001-2016        65-74        None        Count  People
# 106     89  2001-2016  75 and over        None        Count  People
# 107     54  2001-2016   Median Age  Median Age        Count  People
#
# [108 rows x 6 columns]

# %%
new_table = new_table[['Year','Age','Measure Type','Value','Unit']]

# %%
new_table.head(5)
# Out:
#    Year       Age Measure Type  Value    Unit
# 0  2006  All Ages        Count    210  People
# 1  2006  Under 25        Count      1  People
# 2  2006     25-34        Count      5  People
# 3  2006     35-44        Count     40  People
# 4  2006     45-54        Count     78  People

# %%
destinationFolder = Path('out')
destinationFolder.mkdir(exist_ok=True, parents=True)

new_table.to_csv(destinationFolder / ('tab2a.csv'), index = False)
