# %% [markdown]
# Table 4a: Number of alcohol related deaths by Health and Social Care Trust and registration year, 2006-2016

# %%
from databaker.framework import *
import pandas as pd

# %%
import requests
from cachecontrol import CacheControl
from cachecontrol.caches.file_cache import FileCache
from cachecontrol.heuristics import LastModified
from pathlib import Path

session = CacheControl(requests.Session(),
                       cache=FileCache('.cache'),
                       heuristic=LastModified())

sourceFolder = Path('in')
sourceFolder.mkdir(exist_ok=True)

inputURL = 'https://www.nisra.gov.uk/sites/nisra.gov.uk/files/publications/Alcohol_Tables_16_0.xls'
inputFile = sourceFolder / 'Alcohol_Tables_16_0.xls'
response = session.get(inputURL)
with open(inputFile, 'wb') as f:
  f.write(response.content)

# %%
tab = loadxlstabs(inputFile, sheetids='Table 4a')[0]
# Out:
# Loading in\Alcohol_Tables_16_0.xls which has size 969216 bytes
# Table names: ['Table 4a']

# %%
observations = tab.excel_ref('B5').expand(DOWN).expand(RIGHT).is_not_blank()

# %%
observations
# Out:
# {<G14 282.0>, <B5 60.0>, <E5 28.0>, <E14 44.0>, <G16 2668.0>, <F10 36.0>, <B9 71.0>, <C15 62.0>, <F6 41.0>, <D15 50.0>, <B13 61.0>, <F14 56.0>, <E6 38.0>, <G11 244.0>, <G6 238.0>, <G7 243.0>, <E7 29.0>, <D11 43.0>, <E9 44.0>, <G15 289.0>, <D6 36.0>, <B6 74.0>, <F12 42.0>, <C7 63.0>, <F8 48.0>, <B10 67.0>, <G5 210.0>, <G8 249.0>, <F5 38.0>, <G13 219.0>, <B15 88.0>, <C11 38.0>, <D10 47.0>, <F16 493.0>, <D13 38.0>, <F7 30.0>, <E8 37.0>, <B8 67.0>, <E12 31.0>, <E11 41.0>, <C8 52.0>, <E13 36.0>, <F9 62.0>, <D16 457.0>, <G10 228.0>, <D7 46.0>, <B12 55.0>, <B14 69.0>, <F15 55.0>, <E10 33.0>, <C16 563.0>, <G12 206.0>, <E16 395.0>, <C9 45.0>, <B11 73.0>, <C12 46.0>, <D14 47.0>, <D9 38.0>, <F11 49.0>, <B16 760.0>, <C10 45.0>, <C5 49.0>, <D12 32.0>, <F13 36.0>, <G9 260.0>, <D5 35.0>, <C6 49.0>, <C13 48.0>, <D8 45.0>, <B7 75.0>, <C14 66.0>, <E15 34.0>}

# %%
Year = tab.excel_ref('A5').expand(DOWN).is_not_blank() - tab.excel_ref('A17').expand(DOWN)
Year
# Out:
# {<A8 2009.0>, <A11 2012.0>, <A7 2008.0>, <A15 2016.0>, <A14 2015.0>, <A9 2010.0>, <A5 2006.0>, <A16 'Total (2006-2016)'>, <A10 2011.0>, <A6 2007.0>, <A13 2014.0>, <A12 2013.0>}

# %%
sct = tab.excel_ref('B4').expand(RIGHT).is_not_blank()
sct
# Out:
# {<D4 'South Eastern'>, <C4 'Northern'>, <F4 'Western'>, <B4 'Belfast'>, <E4 ' Southern'>}

# %%
Dimensions = [
            HDim(Year,'Year',DIRECTLY,LEFT),
            HDim(sct, 'Social Care Trust',DIRECTLY,ABOVE),
            HDimConst('Measure Type', 'Count'),
            HDimConst('Unit','People')
            ]

# %%
c1 = ConversionSegment(observations, Dimensions, processTIMEUNIT=True)
savepreviewhtml(c1)
# Out:
# <div id="injblock1001">
# <style>
# table.ex, table.exkey { border: thin black solid }
# table.ex td, table.ex tr { border: none }
# table.ex td:hover { border: thin blue solid }
# table.ex td.excOBS:hover { border: thin red solid }
# table.ex td.selected { border: thick red solid }
# </style>
#
#
# <table class="exkey">
# <tr><td class="xc0" style="background-color:Aqua">OBS</td><td class="xc1" style="background-color:LightGreen">Year</td><td class="xc2" style="background-color:MistyRose">Social Care Trust</td></tr></table>
#
# <table class="ex">
# <caption style="text-align:center; padding:0px; caption-side:bottom">Table 4a</caption>
# <tr><td style="font-weight:bold" title="0 0">Table 4a: Number of alcohol related deaths by Health and Social Care Trust and registration year, 2006-2016 - (new definition)</td><td title="1 0"></td><td title="2 0"></td><td title="3 0"></td><td title="4 0"></td><td title="5 0"></td><td title="6 0"></td></tr>
# <tr><td title="0 1"></td><td title="1 1"></td><td title="2 1"></td><td title="3 1"></td><td title="4 1"></td><td title="5 1"></td><td title="6 1"></td></tr>
# <tr><td style="font-weight:bold" title="0 2">Registration Year</td><td style="font-weight:bold" title="1 2">Health and Social Care Trust</td><td style="font-weight:bold" title="2 2"></td><td style="font-weight:bold" title="3 2"></td><td style="font-weight:bold" title="4 2"></td><td style="font-weight:bold" title="5 2"></td><td style="font-weight:bold" title="6 2">Total</td></tr>
# <tr><td style="font-weight:bold" title="0 3"></td><td style="background-color:MistyRose;font-weight:bold" title="1 3">Belfast</td><td style="background-color:MistyRose;font-weight:bold" title="2 3">Northern</td><td style="background-color:MistyRose;font-weight:bold" title="3 3">South Eastern</td><td style="background-color:MistyRose;font-weight:bold" title="4 3"> Southern</td><td style="background-color:MistyRose;font-weight:bold" title="5 3">Western</td><td style="font-weight:bold" title="6 3"></td></tr>
# <tr><td style="background-color:LightGreen" title="0 4">2006.0</td><td style="background-color:Aqua" title="1 4">60.0</td><td style="background-color:Aqua" title="2 4">49.0</td><td style="background-color:Aqua" title="3 4">35.0</td><td style="background-color:Aqua" title="4 4">28.0</td><td style="background-color:Aqua" title="5 4">38.0</td><td style="background-color:Aqua;font-weight:bold" title="6 4">210.0</td></tr>
# <tr><td style="background-color:LightGreen" title="0 5">2007.0</td><td style="background-color:Aqua" title="1 5">74.0</td><td style="background-color:Aqua" title="2 5">49.0</td><td style="background-color:Aqua" title="3 5">36.0</td><td style="background-color:Aqua" title="4 5">38.0</td><td style="background-color:Aqua" title="5 5">41.0</td><td style="background-color:Aqua;font-weight:bold" title="6 5">238.0</td></tr>
# <tr><td style="background-color:LightGreen" title="0 6">2008.0</td><td style="background-color:Aqua" title="1 6">75.0</td><td style="background-color:Aqua" title="2 6">63.0</td><td style="background-color:Aqua" title="3 6">46.0</td><td style="background-color:Aqua" title="4 6">29.0</td><td style="background-color:Aqua" title="5 6">30.0</td><td style="background-color:Aqua;font-weight:bold" title="6 6">243.0</td></tr>
# <tr><td style="background-color:LightGreen" title="0 7">2009.0</td><td style="background-color:Aqua" title="1 7">67.0</td><td style="background-color:Aqua" title="2 7">52.0</td><td style="background-color:Aqua" title="3 7">45.0</td><td style="background-color:Aqua" title="4 7">37.0</td><td style="background-color:Aqua" title="5 7">48.0</td><td style="background-color:Aqua;font-weight:bold" title="6 7">249.0</td></tr>
# <tr><td style="background-color:LightGreen" title="0 8">2010.0</td><td style="background-color:Aqua" title="1 8">71.0</td><td style="background-color:Aqua" title="2 8">45.0</td><td style="background-color:Aqua" title="3 8">38.0</td><td style="background-color:Aqua" title="4 8">44.0</td><td style="background-color:Aqua" title="5 8">62.0</td><td style="background-color:Aqua;font-weight:bold" title="6 8">260.0</td></tr>
# <tr><td style="background-color:LightGreen" title="0 9">2011.0</td><td style="background-color:Aqua" title="1 9">67.0</td><td style="background-color:Aqua" title="2 9">45.0</td><td style="background-color:Aqua" title="3 9">47.0</td><td style="background-color:Aqua" title="4 9">33.0</td><td style="background-color:Aqua" title="5 9">36.0</td><td style="background-color:Aqua;font-weight:bold" title="6 9">228.0</td></tr>
# <tr><td style="background-color:LightGreen" title="0 10">2012.0</td><td style="background-color:Aqua" title="1 10">73.0</td><td style="background-color:Aqua" title="2 10">38.0</td><td style="background-color:Aqua" title="3 10">43.0</td><td style="background-color:Aqua" title="4 10">41.0</td><td style="background-color:Aqua" title="5 10">49.0</td><td style="background-color:Aqua;font-weight:bold" title="6 10">244.0</td></tr>
# <tr><td style="background-color:LightGreen" title="0 11">2013.0</td><td style="background-color:Aqua" title="1 11">55.0</td><td style="background-color:Aqua" title="2 11">46.0</td><td style="background-color:Aqua" title="3 11">32.0</td><td style="background-color:Aqua" title="4 11">31.0</td><td style="background-color:Aqua" title="5 11">42.0</td><td style="background-color:Aqua;font-weight:bold" title="6 11">206.0</td></tr>
# <tr><td style="background-color:LightGreen" title="0 12">2014.0</td><td style="background-color:Aqua" title="1 12">61.0</td><td style="background-color:Aqua" title="2 12">48.0</td><td style="background-color:Aqua" title="3 12">38.0</td><td style="background-color:Aqua" title="4 12">36.0</td><td style="background-color:Aqua" title="5 12">36.0</td><td style="background-color:Aqua;font-weight:bold" title="6 12">219.0</td></tr>
# <tr><td style="background-color:LightGreen" title="0 13">2015.0</td><td style="background-color:Aqua" title="1 13">69.0</td><td style="background-color:Aqua" title="2 13">66.0</td><td style="background-color:Aqua" title="3 13">47.0</td><td style="background-color:Aqua" title="4 13">44.0</td><td style="background-color:Aqua" title="5 13">56.0</td><td style="background-color:Aqua;font-weight:bold" title="6 13">282.0</td></tr>
# <tr><td style="background-color:LightGreen" title="0 14">2016.0</td><td style="background-color:Aqua" title="1 14">88.0</td><td style="background-color:Aqua" title="2 14">62.0</td><td style="background-color:Aqua" title="3 14">50.0</td><td style="background-color:Aqua" title="4 14">34.0</td><td style="background-color:Aqua" title="5 14">55.0</td><td style="background-color:Aqua;font-weight:bold" title="6 14">289.0</td></tr>
# <tr><td style="background-color:LightGreen;font-weight:bold" title="0 15">Total (2006-2016)</td><td style="background-color:Aqua;font-weight:bold" title="1 15">760.0</td><td style="background-color:Aqua;font-weight:bold" title="2 15">563.0</td><td style="background-color:Aqua;font-weight:bold" title="3 15">457.0</td><td style="background-color:Aqua;font-weight:bold" title="4 15">395.0</td><td style="background-color:Aqua;font-weight:bold" title="5 15">493.0</td><td style="background-color:Aqua;font-weight:bold" title="6 15">2668.0</td></tr>
# <tr><td title="0 16"></td><td title="1 16"></td><td title="2 16"></td><td title="3 16"></td><td title="4 16"></td><td title="5 16"></td><td title="6 16"></td></tr>
# <tr><td title="0 17">Note: A revised definition of alcohol-specific deaths has been used to produce these statistics.</td><td title="1 17"></td><td title="2 17"></td><td title="3 17"></td><td title="4 17"></td><td title="5 17"></td><td title="6 17"></td></tr>
# <tr><td title="0 18">Please see the 'Notes' section for further details.</td><td title="1 18"></td><td title="2 18"></td><td title="3 18"></td><td title="4 18"></td><td title="5 18"></td><td title="6 18"></td></tr>
# </table>
#
# </div>
#
# <script>
# var jslookup = {"6 13":[0,13],"1 4":[0,4,1,3],"4 4":[0,4,4,3],"4 13":[0,13,4,3],"6 15":[0,15],"5 9":[0,9,5,3],"1 8":[0,8,1,3],"2 14":[0,14,2,3],

# %%
new_table = c1.topandas()
new_table
# Out:
#        OBS               Year Social Care Trust Measure Type    Unit
# 0     60.0             2006.0           Belfast        Count  People
# 1     49.0             2006.0          Northern        Count  People
# 2     35.0             2006.0     South Eastern        Count  People
# 3     28.0             2006.0          Southern        Count  People
# 4     38.0             2006.0           Western        Count  People
# 5    210.0             2006.0              None        Count  People
# 6     74.0             2007.0           Belfast        Count  People
# 7     49.0             2007.0          Northern        Count  People
# 8     36.0             2007.0     South Eastern        Count  People
# 9     38.0             2007.0          Southern        Count  People
# 10    41.0             2007.0           Western        Count  People
# 11   238.0             2007.0              None        Count  People
# 12    75.0             2008.0           Belfast        Count  People
# 13    63.0             2008.0          Northern        Count  People
# 14    46.0             2008.0     South Eastern        Count  People
# 15    29.0             2008.0          Southern        Count  People
# 16    30.0             2008.0           Western        Count  People
# 17   243.0             2008.0              None        Count  People
# 18    67.0             2009.0           Belfast        Count  People
# 19    52.0             2009.0          Northern        Count  People
# 20    45.0             2009.0     South Eastern        Count  People
# 21    37.0             2009.0          Southern        Count  People
# 22    48.0             2009.0           Western        Count  People
# 23   249.0             2009.0              None        Count  People
# 24    71.0             2010.0           Belfast        Count  People
# 25    45.0             2010.0          Northern        Count  People
# 26    38.0             2010.0     South Eastern        Count  People
# 27    44.0             2010.0          Southern        Count  People
# 28    62.0             2010.0           Western        Count  People
# 29   260.0             2010.0              None        Count  People
# ..     ...                ...               ...          ...     ...
# 42    55.0             2013.0           Belfast        Count  People
# 43    46.0             2013.0          Northern        Count  People
# 44    32.0             2013.0     South Eastern        Count  People
# 45    31.0             2013.0          Southern        Count  People
# 46    42.0             2013.0           Western        Count  People
# 47   206.0             2013.0              None        Count  People
# 48    61.0             2014.0           Belfast        Count  People
# 49    48.0             2014.0          Northern        Count  People
# 50    38.0             2014.0     South Eastern        Count  People
# 51    36.0             2014.0          Southern        Count  People
# 52    36.0             2014.0           Western        Count  People
# 53   219.0             2014.0              None        Count  People
# 54    69.0             2015.0           Belfast        Count  People
# 55    66.0             2015.0          Northern        Count  People
# 56    47.0             2015.0     South Eastern        Count  People
# 57    44.0             2015.0          Southern        Count  People
# 58    56.0             2015.0           Western        Count  People
# 59   282.0             2015.0              None        Count  People
# 60    88.0             2016.0           Belfast        Count  People
# 61    62.0             2016.0          Northern        Count  People
# 62    50.0             2016.0     South Eastern        Count  People
# 63    34.0             2016.0          Southern        Count  People
# 64    55.0             2016.0           Western        Count  People
# 65   289.0             2016.0              None        Count  People
# 66   760.0  Total (2006-2016)           Belfast        Count  People
# 67   563.0  Total (2006-2016)          Northern        Count  People
# 68   457.0  Total (2006-2016)     South Eastern        Count  People
# 69   395.0  Total (2006-2016)          Southern        Count  People
# 70   493.0  Total (2006-2016)           Western        Count  People
# 71  2668.0  Total (2006-2016)              None        Count  People
#
# [72 rows x 5 columns]

# %%
new_table['Social Care Trust'].fillna('Total', inplace = True)

# %%
new_table['Year'] = pd.to_numeric(new_table['Year'], errors='coerce').fillna(0)

# %%
new_table['Year'] = new_table['Year'].astype(int)

# %%
new_table.columns = ['Value' if x=='OBS' else x for x in new_table.columns]

# %%
new_table['Year'] = new_table['Year'].astype(str)

# %%
new_table.count()
# Out:
# Value                72
# Year                 72
# Social Care Trust    72
# Measure Type         72
# Unit                 72
# dtype: int64

# %%
new_table['Value'] = new_table['Value'].astype(int)

# %%
new_table.dtypes
# Out:
# Value                 int32
# Year                 object
# Social Care Trust    object
# Measure Type         object
# Unit                 object
# dtype: object

# %%
new_table.tail(5)
# Out:
#     Value Year Social Care Trust Measure Type    Unit
# 67    563    0          Northern        Count  People
# 68    457    0     South Eastern        Count  People
# 69    395    0          Southern        Count  People
# 70    493    0           Western        Count  People
# 71   2668    0             Total        Count  People

# %%
def user_perc(x):
    
    if str(x) == '0':
        return '2006-2016'
    else:
        return x
    
new_table['Year'] = new_table.apply(lambda row: user_perc(row['Year']), axis = 1)

# %%
new_table
# Out:
#     Value       Year Social Care Trust Measure Type    Unit
# 0      60       2006           Belfast        Count  People
# 1      49       2006          Northern        Count  People
# 2      35       2006     South Eastern        Count  People
# 3      28       2006          Southern        Count  People
# 4      38       2006           Western        Count  People
# 5     210       2006             Total        Count  People
# 6      74       2007           Belfast        Count  People
# 7      49       2007          Northern        Count  People
# 8      36       2007     South Eastern        Count  People
# 9      38       2007          Southern        Count  People
# 10     41       2007           Western        Count  People
# 11    238       2007             Total        Count  People
# 12     75       2008           Belfast        Count  People
# 13     63       2008          Northern        Count  People
# 14     46       2008     South Eastern        Count  People
# 15     29       2008          Southern        Count  People
# 16     30       2008           Western        Count  People
# 17    243       2008             Total        Count  People
# 18     67       2009           Belfast        Count  People
# 19     52       2009          Northern        Count  People
# 20     45       2009     South Eastern        Count  People
# 21     37       2009          Southern        Count  People
# 22     48       2009           Western        Count  People
# 23    249       2009             Total        Count  People
# 24     71       2010           Belfast        Count  People
# 25     45       2010          Northern        Count  People
# 26     38       2010     South Eastern        Count  People
# 27     44       2010          Southern        Count  People
# 28     62       2010           Western        Count  People
# 29    260       2010             Total        Count  People
# ..    ...        ...               ...          ...     ...
# 42     55       2013           Belfast        Count  People
# 43     46       2013          Northern        Count  People
# 44     32       2013     South Eastern        Count  People
# 45     31       2013          Southern        Count  People
# 46     42       2013           Western        Count  People
# 47    206       2013             Total        Count  People
# 48     61       2014           Belfast        Count  People
# 49     48       2014          Northern        Count  People
# 50     38       2014     South Eastern        Count  People
# 51     36       2014          Southern        Count  People
# 52     36       2014           Western        Count  People
# 53    219       2014             Total        Count  People
# 54     69       2015           Belfast        Count  People
# 55     66       2015          Northern        Count  People
# 56     47       2015     South Eastern        Count  People
# 57     44       2015          Southern        Count  People
# 58     56       2015           Western        Count  People
# 59    282       2015             Total        Count  People
# 60     88       2016           Belfast        Count  People
# 61     62       2016          Northern        Count  People
# 62     50       2016     South Eastern        Count  People
# 63     34       2016          Southern        Count  People
# 64     55       2016           Western        Count  People
# 65    289       2016             Total        Count  People
# 66    760  2006-2016           Belfast        Count  People
# 67    563  2006-2016          Northern        Count  People
# 68    457  2006-2016     South Eastern        Count  People
# 69    395  2006-2016          Southern        Count  People
# 70    493  2006-2016           Western        Count  People
# 71   2668  2006-2016             Total        Count  People
#
# [72 rows x 5 columns]

# %%
new_table = new_table[['Year','Social Care Trust','Measure Type','Value','Unit']]

# %%
new_table.head(5)
# Out:
#    Year Social Care Trust Measure Type  Value    Unit
# 0  2006           Belfast        Count     60  People
# 1  2006          Northern        Count     49  People
# 2  2006     South Eastern        Count     35  People
# 3  2006          Southern        Count     28  People
# 4  2006           Western        Count     38  People

# %%
destinationFolder = Path('out')
destinationFolder.mkdir(exist_ok=True, parents=True)

new_table.to_csv(destinationFolder / ('tab4a.csv'), index = False)
